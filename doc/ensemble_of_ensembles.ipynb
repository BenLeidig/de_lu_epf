# %% [markdown]
# # Direct Strategy Ensembles

# %% [markdown]
# ## Requirements

# %%
import numpy as np
import pandas as pd

import xgboost as xgb


pd.set_option('display.max_rows', 100)
pd.set_option('display.max_columns', 100)
# sns.set_context('paper')

# %%
df = pd.read_csv('../data/raw/dataset_2022_2025.csv', index_col='datetime')
