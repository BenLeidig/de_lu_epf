# %% [markdown]
# # Hybrid Deep Ensemble Respective Model Optimization
#
# ## Table of Contents
# * [Requirements](#requirements)
# * [IMF-1](#imf-1)
# * [IMF-2](#imf-2)
# * [IMF-3](#imf-3)
# * [IMF-4](#imf-4)
# * [IMF-5](#imf-5)
# * [IMF-6](#imf-6)
# * [IMF-7](#imf-7)
# * [IMF-8](#imf-8)
# * [IMF-9](#imf-9)
#
# ----

# %% [markdown]
# ## Requirements

# %%
import sys
import joblib

import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import TimeSeriesSplit
from sklearn.linear_model import LinearRegression

import torch

import optuna

sys.path.append('../../src')
from ann_models import create_nn_objective, GRU

pd.set_option('display.max_rows', 100)
pd.set_option('display.max_columns', 100)
sns.set_context('paper')

# %% [markdown]
# ----

# %% [markdown]
# ## IMF-1

# %%
imf = 1

X_train_val = pd.read_csv(f'../../data/processed/imf{imf}/imf{imf}_x_train_val.csv', index_col='datetime').to_numpy()
y_train_val = pd.read_csv(f'../../data/processed/imf{imf}/imf{imf}_y_train_val.csv', index_col='datetime').to_numpy()

X_train = X_train_val[:-14_016]
y_train = y_train_val[:-14_016]
X_val = X_train_val[-14_016:]
y_val = y_train_val[-14_016:]

objective = create_nn_objective(
    model_class=GRU, scaler_class=StandardScaler,
    X_train=X_train, y_train=y_train,
    X_val=X_val, y_val=y_val,
    search_space={'lr':{'method':'suggest_float', 'low':1e-5, 'high':1e-2, 'log':True}}
)
study = optuna.create_study(
    direction='minimize',
    sampler=optuna.samplers.TPESampler(seed=0),
    pruner=optuna.pruners.HyperbandPruner(min_resource=5, max_resource=100),
    study_name=f'imf{imf}_gru_tpe_hyperband'
)
study.optimize(objective, n_trials=50)
best_state = study.best_trial.user_attrs['best_state_dict']
torch.save(best_state, f'../../models/hde_respective_models/imf{imf}_gru_state_dict.pth')
# Out:
# [I 2026-01-21 22:45:35,858] A new study created in memory with name: imf1_gru_tpe_hyperband
# [I 2026-01-21 22:47:17,485] Trial 0 finished with value: 2.9611284732818604 and parameters: {'lr': 0.00044303752452182633}. Best is trial 0 with value: 2.9611284732818604.
# [I 2026-01-21 22:48:54,377] Trial 1 finished with value: 2.964674472808838 and parameters: {'lr': 0.0013981961408994052}. Best is trial 0 with value: 2.9611284732818604.
# [I 2026-01-21 22:50:32,703] Trial 2 finished with value: 2.965398073196411 and parameters: {'lr': 0.0006431172050131992}. Best is trial 0 with value: 2.9611284732818604.
# [I 2026-01-21 22:52:12,005] Trial 3 finished with value: 2.9270236492156982 and parameters: {'lr': 0.0004311710058685492}. Best is trial 3 with value: 2.9270236492156982.
# [I 2026-01-21 22:53:48,453] Trial 4 finished with value: 2.9678008556365967 and parameters: {'lr': 0.00018662266976517984}. Best is trial 3 with value: 2.9270236492156982.
# ...

# %% [markdown]
# ----

# %% [markdown]
# ## IMF-2

# %%
imf = 2

X_train_val = pd.read_csv(f'../../data/processed/imf{imf}/imf{imf}_x_train_val.csv', index_col='datetime').to_numpy()
y_train_val = pd.read_csv(f'../../data/processed/imf{imf}/imf{imf}_y_train_val.csv', index_col='datetime').to_numpy()

X_train = X_train_val[:-14_016]
y_train = y_train_val[:-14_016]
X_val = X_train_val[-14_016:]
y_val = y_train_val[-14_016:]

objective = create_nn_objective(
    model_class=GRU, scaler_class=StandardScaler,
    X_train=X_train, y_train=y_train,
    X_val=X_val, y_val=y_val,
    search_space={'lr':{'method':'suggest_float', 'low':1e-5, 'high':1e-2, 'log':True}}
)
study = optuna.create_study(
    direction='minimize',
    sampler=optuna.samplers.TPESampler(seed=0),
    pruner=optuna.pruners.HyperbandPruner(min_resource=5, max_resource=100),
    study_name=f'imf{imf}_gru_tpe_hyperband'
)
study.optimize(objective, n_trials=50)
best_state = study.best_trial.user_attrs['best_state_dict']
torch.save(best_state, f'../../models/hde_respective_models/imf{imf}_gru_state_dict.pth')
# Out:
# [I 2026-01-21 23:17:16,496] A new study created in memory with name: imf2_gru_tpe_hyperband
# [I 2026-01-21 23:18:48,592] Trial 0 finished with value: 0.8176094889640808 and parameters: {'lr': 0.00044303752452182633}. Best is trial 0 with value: 0.8176094889640808.
# [I 2026-01-21 23:20:20,678] Trial 1 finished with value: 0.7983913421630859 and parameters: {'lr': 0.0013981961408994052}. Best is trial 1 with value: 0.7983913421630859.
# [I 2026-01-21 23:21:02,918] Trial 2 pruned.
# [I 2026-01-21 23:21:45,231] Trial 3 pruned.
# [I 2026-01-21 23:21:50,760] Trial 4 pruned.
# [I 2026-01-21 23:23:22,620] Trial 5 finished with value: 0.7757958173751831 and parameters: {'lr': 0.0008663279761354553}. Best is trial 5 with value: 0.7757958173751831.
# [I 2026-01-21 23:23:28,143] Trial 6 pruned.
# [I 2026-01-21 23:23:42,889] Trial 7 pruned.
# [I 2026-01-21 23:23:48,434] Trial 8 pruned.
# [I 2026-01-21 23:24:03,145] Trial 9 pruned.
# [I 2026-01-21 23:24:08,676] Trial 10 pruned.
# ...

# %% [markdown]
# ----

# %% [markdown]
# ## IMF-3

# %%
imf = 3

X_train_val = pd.read_csv(f'../../data/processed/imf{imf}/imf{imf}_x_train_val.csv', index_col='datetime').to_numpy()
y_train_val = pd.read_csv(f'../../data/processed/imf{imf}/imf{imf}_y_train_val.csv', index_col='datetime').to_numpy()

X_train = X_train_val[:-14_016]
y_train = y_train_val[:-14_016]
X_val = X_train_val[-14_016:]
y_val = y_train_val[-14_016:]

objective = create_nn_objective(
    model_class=GRU, scaler_class=StandardScaler,
    X_train=X_train, y_train=y_train,
    X_val=X_val, y_val=y_val,
    search_space={'lr':{'method':'suggest_float', 'low':1e-5, 'high':1e-2, 'log':True}}
)
study = optuna.create_study(
    direction='minimize',
    sampler=optuna.samplers.TPESampler(seed=0),
    pruner=optuna.pruners.HyperbandPruner(min_resource=5, max_resource=100),
    study_name=f'imf{imf}_gru_tpe_hyperband'
)
study.optimize(objective, n_trials=50)
best_state = study.best_trial.user_attrs['best_state_dict']
torch.save(best_state, f'../../models/hde_respective_models/imf{imf}_gru_state_dict.pth')
# Out:
# [I 2026-01-21 23:44:42,772] A new study created in memory with name: imf3_gru_tpe_hyperband
# [I 2026-01-21 23:46:14,807] Trial 0 finished with value: 0.6612005233764648 and parameters: {'lr': 0.00044303752452182633}. Best is trial 0 with value: 0.6612005233764648.
# [I 2026-01-21 23:47:46,709] Trial 1 finished with value: 0.6202656030654907 and parameters: {'lr': 0.0013981961408994052}. Best is trial 1 with value: 0.6202656030654907.
# [I 2026-01-21 23:49:18,550] Trial 2 finished with value: 0.6280824542045593 and parameters: {'lr': 0.0006431172050131992}. Best is trial 1 with value: 0.6202656030654907.
# [I 2026-01-21 23:49:33,279] Trial 3 pruned.
# [I 2026-01-21 23:49:48,021] Trial 4 pruned.
# [I 2026-01-21 23:51:19,886] Trial 5 finished with value: 0.6269826292991638 and parameters: {'lr': 0.0008663279761354553}. Best is trial 1 with value: 0.6202656030654907.
# [I 2026-01-21 23:51:25,417] Trial 6 pruned.
# [I 2026-01-21 23:51:40,159] Trial 7 pruned.
# ...

# %% [markdown]
# ----

# %% [markdown]
# ## IMF-4

# %%
imf = 4

X_train_val = pd.read_csv(f'../../data/processed/imf{imf}/imf{imf}_x_train_val.csv', index_col='datetime').to_numpy()
y_train_val = pd.read_csv(f'../../data/processed/imf{imf}/imf{imf}_y_train_val.csv', index_col='datetime').to_numpy()

X_train = X_train_val[:-14_016]
y_train = y_train_val[:-14_016]
X_val = X_train_val[-14_016:]
y_val = y_train_val[-14_016:]

objective = create_nn_objective(
    model_class=GRU, scaler_class=StandardScaler,
    X_train=X_train, y_train=y_train,
    X_val=X_val, y_val=y_val,
    search_space={'lr':{'method':'suggest_float', 'low':1e-5, 'high':1e-2, 'log':True}}
)
study = optuna.create_study(
    direction='minimize',
    sampler=optuna.samplers.TPESampler(seed=0),
    pruner=optuna.pruners.HyperbandPruner(min_resource=5, max_resource=100),
    study_name=f'imf{imf}_gru_tpe_hyperband'
)
study.optimize(objective, n_trials=50)
best_state = study.best_trial.user_attrs['best_state_dict']
torch.save(best_state, f'../../models/hde_respective_models/imf{imf}_gru_state_dict.pth')
# Out:
# [I 2026-01-22 00:10:25,379] A new study created in memory with name: imf4_gru_tpe_hyperband
# [I 2026-01-22 00:11:57,842] Trial 0 finished with value: 0.41103774309158325 and parameters: {'lr': 0.00044303752452182633}. Best is trial 0 with value: 0.41103774309158325.
# [I 2026-01-22 00:13:30,266] Trial 1 finished with value: 0.41022518277168274 and parameters: {'lr': 0.0013981961408994052}. Best is trial 1 with value: 0.41022518277168274.
# [I 2026-01-22 00:13:35,844] Trial 2 pruned.
# [I 2026-01-22 00:15:08,312] Trial 3 finished with value: 0.41775697469711304 and parameters: {'lr': 0.0004311710058685492}. Best is trial 1 with value: 0.41022518277168274.
# [I 2026-01-22 00:15:13,882] Trial 4 pruned.
# [I 2026-01-22 00:15:28,696] Trial 5 pruned.
# [I 2026-01-22 00:15:34,274] Trial 6 pruned.
# [I 2026-01-22 00:17:06,849] Trial 7 finished with value: 0.4566352069377899 and parameters: {'lr': 0.004734989304499477}. Best is trial 1 with value: 0.41022518277168274.
# ...

# %% [markdown]
# ----

# %% [markdown]
# ## IMF-5

# %%
imf = 5

X_train_val = pd.read_csv(f'../../data/processed/imf{imf}/imf{imf}_x_train_val.csv', index_col='datetime').to_numpy()
y_train_val = pd.read_csv(f'../../data/processed/imf{imf}/imf{imf}_y_train_val.csv', index_col='datetime').to_numpy()

X_train = X_train_val[:-14_016]
y_train = y_train_val[:-14_016]
X_val = X_train_val[-14_016:]
y_val = y_train_val[-14_016:]

objective = create_nn_objective(
    model_class=GRU, scaler_class=StandardScaler,
    X_train=X_train, y_train=y_train,
    X_val=X_val, y_val=y_val,
    search_space={'lr':{'method':'suggest_float', 'low':1e-5, 'high':1e-2, 'log':True}}
)
study = optuna.create_study(
    direction='minimize',
    sampler=optuna.samplers.TPESampler(seed=0),
    pruner=optuna.pruners.HyperbandPruner(min_resource=5, max_resource=100),
    study_name=f'imf{imf}_gru_tpe_hyperband'
)
study.optimize(objective, n_trials=50)
best_state = study.best_trial.user_attrs['best_state_dict']
torch.save(best_state, f'../../models/hde_respective_models/imf{imf}_gru_state_dict.pth')
# Out:
# [I 2026-01-22 00:36:38,989] A new study created in memory with name: imf5_gru_tpe_hyperband
# [I 2026-01-22 00:38:15,378] Trial 0 finished with value: 0.33400577306747437 and parameters: {'lr': 0.00044303752452182633}. Best is trial 0 with value: 0.33400577306747437.
# [I 2026-01-22 00:39:51,276] Trial 1 finished with value: 0.3288414478302002 and parameters: {'lr': 0.0013981961408994052}. Best is trial 1 with value: 0.3288414478302002.
# [I 2026-01-22 00:41:27,043] Trial 2 finished with value: 0.33800485730171204 and parameters: {'lr': 0.0006431172050131992}. Best is trial 1 with value: 0.3288414478302002.
# [I 2026-01-22 00:43:02,930] Trial 3 finished with value: 0.3592049777507782 and parameters: {'lr': 0.0004311710058685492}. Best is trial 1 with value: 0.3288414478302002.
# [I 2026-01-22 00:43:18,347] Trial 4 pruned.
# [I 2026-01-22 00:43:33,699] Trial 5 pruned.
# [I 2026-01-22 00:43:39,480] Trial 6 pruned.
# [I 2026-01-22 00:43:54,866] Trial 7 pruned.
# ...

# %% [markdown]
# ----

# %% [markdown]
# ## IMF-6

# %%
imf = 6

X_train_val = pd.read_csv(f'../../data/processed/imf{imf}/imf{imf}_x_train_val.csv', index_col='datetime').to_numpy()
y_train_val = pd.read_csv(f'../../data/processed/imf{imf}/imf{imf}_y_train_val.csv', index_col='datetime').to_numpy()

X_train = X_train_val[:-14_016]
y_train = y_train_val[:-14_016]
X_val = X_train_val[-14_016:]
y_val = y_train_val[-14_016:]

objective = create_nn_objective(
    model_class=GRU, scaler_class=StandardScaler,
    X_train=X_train, y_train=y_train,
    X_val=X_val, y_val=y_val,
    search_space={'lr':{'method':'suggest_float', 'low':1e-5, 'high':1e-2, 'log':True}}
)
study = optuna.create_study(
    direction='minimize',
    sampler=optuna.samplers.TPESampler(seed=0),
    pruner=optuna.pruners.HyperbandPruner(min_resource=5, max_resource=100),
    study_name=f'imf{imf}_gru_tpe_hyperband'
)
study.optimize(objective, n_trials=50)
best_state = study.best_trial.user_attrs['best_state_dict']
torch.save(best_state, f'../../models/hde_respective_models/imf{imf}_gru_state_dict.pth')
# Out:
# [I 2026-01-22 00:59:44,635] A new study created in memory with name: imf6_gru_tpe_hyperband
# [I 2026-01-22 01:01:19,867] Trial 0 finished with value: 0.06708557158708572 and parameters: {'lr': 0.00044303752452182633}. Best is trial 0 with value: 0.06708557158708572.
# [I 2026-01-22 01:02:54,914] Trial 1 finished with value: 0.06454148888587952 and parameters: {'lr': 0.0013981961408994052}. Best is trial 1 with value: 0.06454148888587952.
# [I 2026-01-22 01:04:29,904] Trial 2 finished with value: 0.057775456458330154 and parameters: {'lr': 0.0006431172050131992}. Best is trial 2 with value: 0.057775456458330154.
# [I 2026-01-22 01:04:35,631] Trial 3 pruned.
# [I 2026-01-22 01:04:50,874] Trial 4 pruned.
# [I 2026-01-22 01:06:25,800] Trial 5 finished with value: 0.05464627221226692 and parameters: {'lr': 0.0008663279761354553}. Best is trial 5 with value: 0.05464627221226692.
# [I 2026-01-22 01:07:09,531] Trial 6 pruned.
# [I 2026-01-22 01:07:24,777] Trial 7 pruned.
# ...

# %% [markdown]
# ----

# %% [markdown]
# ## IMF-7

# %%
imf = 7

X_train_val = pd.read_csv(f'../../data/processed/imf{imf}/imf{imf}_x_train_val.csv', index_col='datetime').to_numpy()
y_train_val = pd.read_csv(f'../../data/processed/imf{imf}/imf{imf}_y_train_val.csv', index_col='datetime').to_numpy()

X_train = X_train_val[:-14_016]
y_train = y_train_val[:-14_016]
X_val = X_train_val[-14_016:]
y_val = y_train_val[-14_016:]

objective = create_nn_objective(
    model_class=GRU, scaler_class=StandardScaler,
    X_train=X_train, y_train=y_train,
    X_val=X_val, y_val=y_val,
    search_space={'lr':{'method':'suggest_float', 'low':1e-5, 'high':1e-2, 'log':True}}
)
study = optuna.create_study(
    direction='minimize',
    sampler=optuna.samplers.TPESampler(seed=0),
    pruner=optuna.pruners.HyperbandPruner(min_resource=5, max_resource=100),
    study_name=f'imf{imf}_gru_tpe_hyperband'
)
study.optimize(objective, n_trials=50)
best_state = study.best_trial.user_attrs['best_state_dict']
torch.save(best_state, f'../../models/hde_respective_models/imf{imf}_gru_state_dict.pth')
# Out:
# [I 2026-01-22 01:23:15,149] A new study created in memory with name: imf7_gru_tpe_hyperband
# [I 2026-01-22 01:24:49,760] Trial 0 finished with value: 0.027009712532162666 and parameters: {'lr': 0.00044303752452182633}. Best is trial 0 with value: 0.027009712532162666.
# [I 2026-01-22 01:26:22,389] Trial 1 finished with value: 0.015927962958812714 and parameters: {'lr': 0.0013981961408994052}. Best is trial 1 with value: 0.015927962958812714.
# [I 2026-01-22 01:26:37,620] Trial 2 pruned.
# [I 2026-01-22 01:28:12,546] Trial 3 finished with value: 0.038035083562135696 and parameters: {'lr': 0.0004311710058685492}. Best is trial 1 with value: 0.015927962958812714.
# [I 2026-01-22 01:28:18,284] Trial 4 pruned.
# [I 2026-01-22 01:29:53,264] Trial 5 finished with value: 0.027168987318873405 and parameters: {'lr': 0.0008663279761354553}. Best is trial 1 with value: 0.015927962958812714.
# [I 2026-01-22 01:29:58,997] Trial 6 pruned.
# [I 2026-01-22 01:30:04,702] Trial 7 pruned.
# ...

# %% [markdown]
# ----

# %% [markdown]
# ## IMF-8

# %%
imf = 8

X_train_val = pd.read_csv(f'../../data/processed/imf{imf}/imf{imf}_x_train_val.csv', index_col='datetime').to_numpy()
y_train_val = pd.read_csv(f'../../data/processed/imf{imf}/imf{imf}_y_train_val.csv', index_col='datetime').to_numpy()

X_train = X_train_val[:-14_016]
y_train = y_train_val[:-14_016]
X_val = X_train_val[-14_016:]
y_val = y_train_val[-14_016:]

objective = create_nn_objective(
    model_class=GRU, scaler_class=StandardScaler,
    X_train=X_train, y_train=y_train,
    X_val=X_val, y_val=y_val,
    search_space={'lr':{'method':'suggest_float', 'low':1e-5, 'high':1e-2, 'log':True}}
)
study = optuna.create_study(
    direction='minimize',
    sampler=optuna.samplers.TPESampler(seed=0),
    pruner=optuna.pruners.HyperbandPruner(min_resource=5, max_resource=100),
    study_name=f'imf{imf}_gru_tpe_hyperband'
)
study.optimize(objective, n_trials=50)
best_state = study.best_trial.user_attrs['best_state_dict']
torch.save(best_state, f'../../models/hde_respective_models/imf{imf}_gru_state_dict.pth')
# Out:
# [I 2026-01-22 01:43:44,077] A new study created in memory with name: imf8_gru_tpe_hyperband
# [I 2026-01-22 01:45:17,691] Trial 0 finished with value: 0.0008509103208780289 and parameters: {'lr': 0.00044303752452182633}. Best is trial 0 with value: 0.0008509103208780289.
# [I 2026-01-22 01:46:51,211] Trial 1 finished with value: 0.0005064979777671397 and parameters: {'lr': 0.0013981961408994052}. Best is trial 1 with value: 0.0005064979777671397.
# [I 2026-01-22 01:47:34,254] Trial 2 pruned.
# [I 2026-01-22 01:47:49,328] Trial 3 pruned.
# [I 2026-01-22 01:48:04,330] Trial 4 pruned.
# [I 2026-01-22 01:49:38,447] Trial 5 finished with value: 0.0005131648504175246 and parameters: {'lr': 0.0008663279761354553}. Best is trial 1 with value: 0.0005064979777671397.
# [I 2026-01-22 01:51:12,322] Trial 6 finished with value: 0.0033569326624274254 and parameters: {'lr': 0.00020547625125911338}. Best is trial 1 with value: 0.0005064979777671397.
# ...

# %% [markdown]
# ----

# %% [markdown]
# ## IMF-9

# %%
imf = 9

X_train_val = pd.read_csv(f'../../data/processed/imf{imf}/imf{imf}_x_train_val.csv', index_col='datetime').to_numpy()
y_train_val = pd.read_csv(f'../../data/processed/imf{imf}/imf{imf}_y_train_val.csv', index_col='datetime').to_numpy()

X_train = X_train_val[:-14_016]
y_train = y_train_val[:-14_016]
X_val = X_train_val[-14_016:]
y_val = y_train_val[-14_016:]

objective = create_nn_objective(
    model_class=GRU, scaler_class=StandardScaler,
    X_train=X_train, y_train=y_train,
    X_val=X_val, y_val=y_val,
    search_space={'lr':{'method':'suggest_float', 'low':1e-5, 'high':1e-2, 'log':True}}
)
study = optuna.create_study(
    direction='minimize',
    sampler=optuna.samplers.TPESampler(seed=0),
    pruner=optuna.pruners.HyperbandPruner(min_resource=5, max_resource=100),
    study_name=f'imf{imf}_gru_tpe_hyperband'
)
study.optimize(objective, n_trials=50)
best_state = study.best_trial.user_attrs['best_state_dict']
torch.save(best_state, f'../../models/hde_respective_models/imf{imf}_gru_state_dict.pth')
# Out:
# [I 2026-01-22 02:09:13,027] A new study created in memory with name: imf9_gru_tpe_hyperband
# [I 2026-01-22 02:10:45,492] Trial 0 finished with value: 2.828890323638916 and parameters: {'lr': 0.00044303752452182633}. Best is trial 0 with value: 2.828890323638916.
# [I 2026-01-22 02:12:17,902] Trial 1 finished with value: 2.758514404296875 and parameters: {'lr': 0.0013981961408994052}. Best is trial 1 with value: 2.758514404296875.
# [I 2026-01-22 02:13:51,203] Trial 2 finished with value: 2.7025840282440186 and parameters: {'lr': 0.0006431172050131992}. Best is trial 2 with value: 2.7025840282440186.
# [I 2026-01-22 02:14:06,229] Trial 3 pruned.
# [I 2026-01-22 02:14:21,234] Trial 4 pruned.
# [I 2026-01-22 02:14:36,244] Trial 5 pruned.
# [I 2026-01-22 02:15:20,242] Trial 6 pruned.
# [I 2026-01-22 02:16:02,275] Trial 7 pruned.
# [I 2026-01-22 02:16:07,771] Trial 8 pruned.
# [I 2026-01-22 02:16:22,395] Trial 9 pruned.
# [I 2026-01-22 02:16:27,905] Trial 10 pruned.
# ...
