# %% [markdown]
# # Respective Optimization

# %% [markdown]
# ## Requirements

# %%
import sys

import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.preprocessing import MinMaxScaler
from sklearn.linear_model import LinearRegression

import torch

sys.path.append('../src')
from ann_models import create_sequences, optimize_gru, GRU

pd.set_option('display.max_rows', 100)
pd.set_option('display.max_columns', 100)
sns.set_context('paper')

# %% [markdown]
# ## IMF-1

# %%
imf = 1
X_train_val = pd.read_csv(f'../data/processed/imf{imf}/imf{imf}_x_train_val.csv', index_col='datetime').to_numpy()
y_train_val = pd.read_csv(f'../data/processed/imf{imf}/imf{imf}_y_train_val.csv', index_col='datetime').to_numpy()
optimize_gru(X_train_val=X_train_val, y_train_val=y_train_val, path=f'../models/imf{imf}_gru_state_dict.pth', batch_size=64)

# %% [markdown]
# ## IMF-2

# %%
imf = 2
X_train_val = pd.read_csv(f'../data/processed/imf{imf}/imf{imf}_x_train_val.csv', index_col='datetime').to_numpy()
y_train_val = pd.read_csv(f'../data/processed/imf{imf}/imf{imf}_y_train_val.csv', index_col='datetime').to_numpy()
optimize_gru(X_train_val=X_train_val, y_train_val=y_train_val, path=f'../models/imf{imf}_gru_state_dict.pth', batch_size=64)

# %% [markdown]
# ## IMF-3

# %%
imf = 3
X_train_val = pd.read_csv(f'../data/processed/imf{imf}/imf{imf}_x_train_val.csv', index_col='datetime').to_numpy()
y_train_val = pd.read_csv(f'../data/processed/imf{imf}/imf{imf}_y_train_val.csv', index_col='datetime').to_numpy()
optimize_gru(X_train_val=X_train_val, y_train_val=y_train_val, path=f'../models/imf{imf}_gru_state_dict.pth', batch_size=64)

# %% [markdown]
# ## IMF-4

# %%
imf = 4
X_train_val = pd.read_csv(f'../data/processed/imf{imf}/imf{imf}_x_train_val.csv', index_col='datetime').to_numpy()
y_train_val = pd.read_csv(f'../data/processed/imf{imf}/imf{imf}_y_train_val.csv', index_col='datetime').to_numpy()
optimize_gru(X_train_val=X_train_val, y_train_val=y_train_val, path=f'../models/imf{imf}_gru_state_dict.pth', batch_size=64)

# %% [markdown]
# ## IMF-5

# %%
imf = 5
X_train_val = pd.read_csv(f'../data/processed/imf{imf}/imf{imf}_x_train_val.csv', index_col='datetime').to_numpy()
y_train_val = pd.read_csv(f'../data/processed/imf{imf}/imf{imf}_y_train_val.csv', index_col='datetime').to_numpy()
optimize_gru(X_train_val=X_train_val, y_train_val=y_train_val, path=f'../models/imf{imf}_gru_state_dict.pth', batch_size=64)

# %% [markdown]
# ## IMF-6

# %%
imf = 6
X_train_val = pd.read_csv(f'../data/processed/imf{imf}/imf{imf}_x_train_val.csv', index_col='datetime').to_numpy()
y_train_val = pd.read_csv(f'../data/processed/imf{imf}/imf{imf}_y_train_val.csv', index_col='datetime').to_numpy()
optimize_gru(X_train_val=X_train_val, y_train_val=y_train_val, path=f'../models/imf{imf}_gru_state_dict.pth', batch_size=64)

# %% [markdown]
# ## IMF-7

# %%
imf = 7
X_train_val = pd.read_csv(f'../data/processed/imf{imf}/imf{imf}_x_train_val.csv', index_col='datetime').to_numpy()
y_train_val = pd.read_csv(f'../data/processed/imf{imf}/imf{imf}_y_train_val.csv', index_col='datetime').to_numpy()
optimize_gru(X_train_val=X_train_val, y_train_val=y_train_val, path=f'../models/imf{imf}_gru_state_dict.pth', batch_size=64)

# %% [markdown]
# ## IMF-8

# %%
imf = 8
X_train_val = pd.read_csv(f'../data/processed/imf{imf}/imf{imf}_x_train_val.csv', index_col='datetime').to_numpy()
y_train_val = pd.read_csv(f'../data/processed/imf{imf}/imf{imf}_y_train_val.csv', index_col='datetime').to_numpy()
optimize_gru(X_train_val=X_train_val, y_train_val=y_train_val, path=f'../models/imf{imf}_gru_state_dict.pth', batch_size=64)

# %% [markdown]
# ## IMF-9

# %%
imf = 9
X_train_val = pd.read_csv(f'../data/processed/imf{imf}/imf{imf}_x_train_val.csv', index_col='datetime').to_numpy()
y_train_val = pd.read_csv(f'../data/processed/imf{imf}/imf{imf}_y_train_val.csv', index_col='datetime').to_numpy()
optimize_gru(X_train_val=X_train_val, y_train_val=y_train_val, path=f'../models/imf{imf}_gru_state_dict.pth', batch_size=64)
