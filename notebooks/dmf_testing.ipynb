# %%
import pandas as pd
from pathlib import Path
import numpy as np
from joblib import load

# %%
df = pd.read_parquet('../data/processed/dmf/test_scaled.parquet')
df
# Out:
#                            0_precipitation  1_precipitation  2_precipitation  \
# datetime
# 2024-01-01 00:00:00+00:00        -0.354145         0.394646        -0.033188
# 2024-01-02 00:00:00+00:00         0.393943        -0.032897         1.356275
# 2024-01-03 00:00:00+00:00        -0.033536         1.356618         0.287457
# 2024-01-04 00:00:00+00:00         1.355770         0.287760         2.745738
# 2024-01-05 00:00:00+00:00         0.287073         2.746133        -0.033188
# ...                                    ...              ...              ...
# 2024-12-27 00:00:00+00:00        -0.354145        -0.353554        -0.140070
# 2024-12-28 00:00:00+00:00        -0.354145        -0.139783         1.676920
# 2024-12-29 00:00:00+00:00        -0.140405         1.677275        -0.140070
# 2024-12-30 00:00:00+00:00         1.676379        -0.139783         0.287457
# 2024-12-31 00:00:00+00:00        -0.140405         0.287760        -0.353834
#
# ...

# %%
BASE_DIR = Path(__file__).parent.parent

load(BASE_DIR / "studies/")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 BASE_DIR = Path(__file__).parent.parent
#       3 load(BASE_DIR / "studies/")
#
# NameError: name '__file__' is not defined

# %%
l = [
    [1,2,3],
    [4, 5, 6]
]
m = np.array(l)
m.flatten()
# Out:
# array([1, 2, 3, 4, 5, 6])

# %%
np
